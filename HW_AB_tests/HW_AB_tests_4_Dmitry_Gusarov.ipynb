# %% [markdown]
# # Домашнее задание 4: Проверка гипотез в A/B-тестах, дисперсионный анализ

# %%
import pandas as pd
import numpy as np
from scipy import stats
from scipy.stats import t
from sklearn.model_selection import train_test_split
from scipy.stats import normaltest
from scipy.stats import ttest_ind

# %% [markdown]
# #### Результаты задания 1 в тесте

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Результаты задания 2 в тесте

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Задание 3. Количество наблюдений в тестовой и контрольной группе. Разница по модулю.

# %% [markdown]
# Проверьте, являются ли дисперсии внутри групп примерно одинаковыми (гомогенными) с помощью теста Левена.
# Это можно сделать с помощью scipy.stats.levene либо pingouin.homoscedasticity
# Какую гипотезу будем проверять этим тестом?

# %%
data = pd.read_csv('AB_lesson4.csv')

# %%
data
# Out:
#           id group  events
# 0      16046     A      14
# 1      18712     A      41
# 2       3268     A      30
# 3      22633     A      37
# 4      28071     A      38
# ...      ...   ...     ...
# 29995  22932     C      38
# 29996  21787     C      25
# 29997   5054     C      34
# 29998  10254     C      27
# 29999   5692     C      49
#
# [30000 rows x 3 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      30000 non-null  int64
#  1   group   30000 non-null  object
#  2   events  30000 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 703.2+ KB

# %%
import scipy.stats as stats

# Проверка гомогенности дисперсий с помощью теста Левена
levene_stat, pval = stats.levene(
    events[group == "A"],
    events[group == "B"],
    events[group == "C"],
)

# Вывод
if pval < 0.05:
    print("Дисперсии групп различны")
else:
    print("Дисперсии групп одинаковы")

# %%
# !pip install pingouin
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.9/198.9 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import pingouin as pg

# Пример кода с использованием pingouin
levene_result = pg.homoscedasticity(data, dv='events', group='group', method='levene')
print(levene_result)
# Out:
#               W      pval  equal_var
# levene  2.26226  0.104133       True

# %% [markdown]
# #### Результаты задания 3 в тесте

# %% [markdown]
# ![image.png](data:image/png;base64,...)
