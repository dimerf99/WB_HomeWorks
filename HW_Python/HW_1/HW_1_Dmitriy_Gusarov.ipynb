# %% [markdown]
# ## 1. Установка Python 3 (от 3.9)

# %% [markdown]
# ![image.png](attachment:ff913538-cbb5-4167-a659-6b39c0060287.png)

# %% [markdown]
# ## 2. Настройка окружения в Poetry

# %% [markdown]
# #### 2.1. Команда для установки Poetry

# %% [markdown]
# ![image.png](attachment:439ab54a-ef8d-4d32-9fba-cfeb2e949a7f.png)

# %% [markdown]
# #### 2.2. Команды для проверки версии Poetry и для создания нового проекта

# %% [markdown]
# ![image.png](attachment:30b7d007-ffcb-4dda-91dc-c42373e7f357.png)

# %% [markdown]
# #### 2.3. Команда для создания виртуальной среды

# %% [markdown]
# ![image.png](attachment:442473aa-dc64-4fb7-ac3b-081ca29fdd60.png)

# %% [markdown]
# ## 3. Установка pandas, numpy и jupyterlab в окружении

# %% [markdown]
# #### 3.1. numpy

# %% [markdown]
# ![image.png](attachment:3f6722f0-792e-4351-94e7-ecf3d5f09c51.png)

# %% [markdown]
# #### 3.2.pandas

# %% [markdown]
# ![image.png](attachment:2397d7d0-b633-4a15-ba39-fa4e2e8fa4da.png)

# %% [markdown]
# #### 3.3.jupyterLab

# %% [markdown]
# ![image.png](attachment:0f1daeb7-0f0b-4a84-9b9c-724b265db86b.png)

# %% [markdown]
# ## 4. Запуск jupyter notebook.
# ## Написание скрипта на питоне, выводящего версии установленных библиотек.

# %%
import numpy as np
import pandas as pd

# %%
np.__version__
# Out:
# '1.26.0'

# %%
pd.__version__
# Out:
# '2.1.1'
